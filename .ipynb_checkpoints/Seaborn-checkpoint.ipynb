# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

# %%
from urllib.request import urlretrieve
url = 'https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt'
urlretrieve(url, 'diabetes.tab.txt')
# Out:
# ('diabetes.tab.txt', <http.client.HTTPMessage at 0x22d77354e08>)

# %%
df = pd.read_csv('diabetes.tab.txt',sep='\t')
df
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
df.rename(columns={'S1':'T_cells', 'S2':'ldl', 'S3':'hdl', 'S4':'tch', 'S5':'ltg', 'S6':'glu'},inplace=True)
df
# Out:
#      AGE  SEX   BMI      BP  T_cells    ldl   hdl   tch     ltg  glu    Y
# 0     59    2  32.1  101.00      157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00      183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00      156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00      198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00      192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...      ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00      185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00      225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67      162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00      201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00      250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %% [markdown]
# # distribution plot
# univarite distribution-- distribution for one variable

# %%
sns.distplot(df['AGE'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AGE', ylabel='Density'>

# %%
sns.histplot(df['AGE'])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %%
sns.histplot(df['AGE'],kde=True)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %%
sns.histplot(df['AGE'],kde=True, bins=5) #5 buckets or bars= 5 bins
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Count'>

# %%
sns.displot(df['AGE'])

# %% [markdown]
# Joint plot

# %%
sns.jointplot(x='BMI',y='BP',data=df, kind="scatter") # kind= "scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %%
sns.jointplot(x='BMI',y='BP',data=df,kind="kde")

# %%
sns.jointplot(x='BMI',y='BP',data=df, kind="hist")

# %%
sns.jointplot(x='BMI',y='BP',data=df, kind="hex")

# %%
sns.jointplot(x='BMI',y='BP',data=df, kind="reg")

# %%
sns.jointplot(x='BMI',y='BP',data=df, kind="resid")

# %% [markdown]
# pair plots

# %%
plt.rcParams['figure.figsize']=[50,60]

sns.pairplot(df)

# %% [markdown]
# rug plot

# %%
plt.rcParams['figure.figsize']=[15,4]

sns.rugplot(df['BP'])
# Out:
# <AxesSubplot:xlabel='BP'>

# %% [markdown]
# STYLING

# %%
sns.set_style('darkgrid') #darkgrid, whitegrid, dark, white, ticks

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_style('whitegrid') #darkgrid, whitegrid, dark, white, ticks

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_style('dark') #darkgrid, whitegrid, dark, white, ticks

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_style('white') #darkgrid, whitegrid, dark, white, ticks

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_style('ticks') #darkgrid, whitegrid, dark, white, ticks

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %% [markdown]
# set context

# %%
sns.set_context('paper',font_scale=2) #paper, notebook, talk, poster

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_context('notebook',font_scale=2) #paper, notebook, talk, poster

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_context('talk') #paper, notebook, talk, poster

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %%
sns.set_context('poster') #paper, notebook, talk, poster

sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %% [markdown]
# DESPINE????

# %%
sns.despine(top=True, right=True, left=False, bottom=False) #    fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False,
sns.jointplot(x='BMI',y='BP',data=df, kind="scatter")

# %% [markdown]
# # categorical plots
# bar plots

# %%
plt.rcParams['figure.figsize']=[20,8]

sns.barplot(x='AGE',y='Y',data=df) #estimator=mean(default)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Y'>

# %%
plt.rcParams['figure.figsize']=[20,8]

sns.barplot(x='AGE',y='Y',data=df, estimator=np.median) #estimator=mean(default)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Y'>

# %%
plt.rcParams['figure.figsize']=[20,8]

sns.barplot(x='AGE',y='Y',data=df, estimator=np.std) #estimator=mean(default)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Y'>

# %%
plt.rcParams['figure.figsize']=[20,8]

sns.barplot(x='AGE',y='Y',data=df, estimator=np.var) #estimator=mean(default)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='Y'>

# %%
plt.rcParams['figure.figsize']=[20,8]

sns.barplot(x='AGE',y='Y',data=df, estimator=np.cov) #estimator=mean(default)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1469: RuntimeWarning: Degrees of freedom <= 0 for slice
#   statistic.append(estimator(stat_data))
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# <AxesSubplot:xlabel='AGE', ylabel='Y'>

# %% [markdown]
# also custom formulas

# %% [markdown]
# ## Count Plot

# %%
sns.countplot(x='AGE',data=df)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %% [markdown]
# ##  Box plot
# gives quartiles of data
# 3 VARIABLES AGE,BMI AND SEX

# %%
sns.boxplot(x='AGE',y='BMI',data=df,hue='SEX')
plt.legend(loc=0)

# %% [markdown]
# ## violin plot
# combination of box plot and kde plot
# box use uses data points
# while violin uses kde estimation

# %%
sns.violinplot(x='AGE',y='BMI',data=df,hue='SEX')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='BMI'>

# %%
sns.violinplot(x='AGE',y='BMI',data=df,hue='SEX',split=True)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='BMI'>

# %% [markdown]
# ## strip plots
# draws scatter plot

# %%
sns.stripplot(x='glu',y='BP',data=df, jitter=True)
# Out:
# <AxesSubplot:xlabel='glu', ylabel='BP'>

# %%
sns.stripplot(x='glu',y='BP',data=df, jitter=True ,hue='SEX')
# Out:
# <AxesSubplot:xlabel='glu', ylabel='BP'>

# %%
sns.stripplot(x='glu',y='BP',data=df, jitter=True ,hue='SEX',dodge=True)
# Out:
# <AxesSubplot:xlabel='glu', ylabel='BP'>

# %% [markdown]
# ## SWARM PLOT
#
# kind of strip plot but points will be adjusted so they dont overlap

# %%
sns.swarmplot(x='SEX',y='BMI',data=df) #color should be diffrent to see swarm plot
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='BMI'>

# %%
sns.violinplot(x='SEX',y='BMI',data=df)
sns.swarmplot(x='SEX',y='BMI',data=df ,color='white') #color should be diffrent to see swarm plot
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='BMI'>

# %%
df.head()
# Out:
#    AGE  SEX   BMI     BP  T_cells    ldl   hdl  tch     ltg  glu    Y
# 0   59    2  32.1  101.0      157   93.2  38.0  4.0  4.8598   87  151
# 1   48    1  21.6   87.0      183  103.2  70.0  3.0  3.8918   69   75
# 2   72    2  30.5   93.0      156   93.6  41.0  4.0  4.6728   85  141
# 3   24    1  25.3   84.0      198  131.4  40.0  5.0  4.8903   89  206
# 4   50    1  23.0  101.0      192  125.4  52.0  4.0  4.2905   80  135

# %% [markdown]
# # [palettes](https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html)

# %%
plt.figure(figsize=(30,8))
sns.set_style('dark')
sns.set_context('talk')

sns.stripplot(x='AGE',y='BMI',data=df, jitter=True ,hue='SEX',palette='magma') #
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='BMI'>

# %% [markdown]
# ### [legend location](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.legend.html)
#
# 'best','upper right','upper left','lower left','lower right','right'	,'center left','center right','lower center','upper center','center'

# %%
plt.figure(figsize=(30,8))
sns.set_style('dark')
sns.set_context('talk')

sns.stripplot(x='AGE',y='BMI',data=df, jitter=True ,hue='SEX',palette='magma') #
plt.legend(loc='upper left')

# %% [markdown]
# # matrix plots

# %% [markdown]
# ### heatmaps
# ## [correlation](https://realpython.com/numpy-scipy-pandas-correlation-python/)
#
# #Correlation Between x and y
# #equal to 1	perfect positive linear relationship
# #greater than 0	positive correlation
# #equal to 0	independent
# #less than 0	negative correlation
# #equal to -1	perfect negative linear relationship

# %%
df_matrix=df.corr() #will be used for making heat map 
df_matrix #show how each feature influences others
# Out:
#               AGE       SEX       BMI        BP   T_cells       ldl       hdl  \
# AGE      1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# SEX      0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# BMI      0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# BP       0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# T_cells  0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# ldl      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# hdl     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# tch      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# ltg      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# glu      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Y        0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...

# %%
plt.figure(figsize=(30,8))
sns.set_context('paper',font_scale=1.4)

sns.heatmap(df_matrix, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df_pivot=df.pivot_table(index='AGE',columns='SEX',values='BMI')
df_pivot
# Out:
# SEX          1          2
# AGE
# 19   22.566667        NaN
# 20   22.900000  23.150000
# 21   22.150000        NaN
# 22   20.200000        NaN
# 23   23.466667  18.000000
# 24   22.833333        NaN
# 25   27.150000  23.466667
# 26   18.800000  30.300000
# 27   22.333333  33.600000
# 28   25.525000  25.225000
# 29   28.000000  18.750000
# 30   21.100000  25.200000
# 31   26.500000  27.150000
# 32   28.500000  27.520000
# 33   24.675000  23.100000
# 34   26.550000  26.450000
# 35   27.660000  25.000000
# 36   24.420000  29.375000
# 37   26.414286  24.875000
# 38   26.650000  29.900000
# 39   21.900000  24.600000
# 40   28.800000  29.133333
# 41   26.766667  26.666667
# 42   26.125000  27.300000
# 43   26.642857        NaN
# 44   25.300000  32.400000
# 45   25.500000  21.200000
# 46   24.780000  27.233333
# 47   30.083333  24.683333
# 48   24.711111  27.460000
# 49   22.750000  26.800000
# 50   26.671429  27.050000
# 51   26.270000  27.483333
# 52   26.637500  25.200000
# ...

# %%
sns.heatmap(df_pivot.T, cmap='Blues',linecolor='green',linewidth=1)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='SEX'>

# %% [markdown]
# # cluster maps
